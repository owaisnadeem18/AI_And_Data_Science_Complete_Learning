# %%
# !pip install pandas

# %%
import pandas as pd

# %%
file = pd.read_csv("/content/data_lec12 (2).csv" , index_col = "Name")

# %%
file.head()
# Out:
#                           Rank Platform    Year         Genre Publisher  \
# Name
# Wii Sports                   1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.            2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii               3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort            4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue     5       GB  1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                   41.49     29.02      3.77         8.46
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.85     12.88      3.79         3.31
# Wii Sports Resort            15.75     11.01      3.28         2.96
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales
# Name
# Wii Sports                       82.74
# ...

# %%
file.shape
# Out:
# (16598, 11)

# %%
file.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
file["Name"].describe
# Out:
# <bound method NDFrame.describe of 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16593                  Woody Woodpecker in Crazy Castle 5
# 16594                       Men in Black II: Alien Escape
# 16595    SCORE International Baja 1000: The Official Game
# 16596                                          Know How 2
# 16597                                    Spirits & Spells
# Name: Name, Length: 16598, dtype: object>

# %%
file.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
file.iloc[20]
# Out:
# Rank                                       21
# Name            Pokemon Diamond/Pokemon Pearl
# Platform                                   DS
# Year                                   2006.0
# Genre                            Role-Playing
# Publisher                            Nintendo
# NA_Sales                                 6.42
# EU_Sales                                 4.52
# JP_Sales                                 6.04
# Other_Sales                              1.37
# Global_Sales                            18.36
# Name: 20, dtype: object

# %%
file.loc["Pokemon Diamond/Pokemon Pearl"]
# Out:
# Rank                      21
# Platform                  DS
# Year                  2006.0
# Genre           Role-Playing
# Publisher           Nintendo
# NA_Sales                6.42
# EU_Sales                4.52
# JP_Sales                6.04
# Other_Sales             1.37
# Global_Sales           18.36
# Name: Pokemon Diamond/Pokemon Pearl, dtype: object

# %%
file.sort_values(by = "Year" , ascending = False).head()
# Out:
#                                                    Rank Platform    Year  \
# Name
# Imagine: Makeup Artist                             5959       DS  2020.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  14393      PS4  2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  16244      PSV  2017.0
# Brothers Conflict: Precious Baby                  16441      PSV  2017.0
# Shin Megami Tensei IV: Final                       8295      3DS  2016.0
#
#                                                          Genre     Publisher  \
# Name
# Imagine: Makeup Artist                              Simulation       Ubisoft
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Brothers Conflict: Precious Baby                        Action  Idea Factory
# Shin Megami Tensei IV: Final                      Role-Playing   Deep Silver
#
# ...

# %%
file[file["Genre"] == "Action"]
# Out:
#                                                      Rank Platform    Year  \
# Name
# Grand Theft Auto V                                     17      PS3  2013.0
# Grand Theft Auto: San Andreas                          18      PS2  2004.0
# Grand Theft Auto V                                     24     X360  2013.0
# Grand Theft Auto: Vice City                            25      PS2  2002.0
# Grand Theft Auto III                                   39      PS2  2001.0
# ...                                                   ...      ...     ...
# Original Frisbee Disc Sports: Ultimate & Golf       16567       DS  2007.0
# Fujiko F. Fujio Characters: Great Assembly! Sli...  16570      3DS  2014.0
# Planet Monsters                                     16585      GBA  2001.0
# Carmageddon 64                                      16586      N64  1999.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
#
#                                                      Genre  \
# ...

# %%
after_2016 = file["Year"] > 2016
file[after_2016]
# Out:
#                                                    Rank Platform    Year  \
# Name
# Imagine: Makeup Artist                             5959       DS  2020.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  14393      PS4  2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  16244      PSV  2017.0
# Brothers Conflict: Precious Baby                  16441      PSV  2017.0
#
#                                                          Genre     Publisher  \
# Name
# Imagine: Makeup Artist                              Simulation       Ubisoft
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Brothers Conflict: Precious Baby                        Action  Idea Factory
#
#                                                   NA_Sales  EU_Sales  \
# Name
# Imagine: Makeup Artist                                0.27       0.0
# ...

# %%
between_2012_to_2014 = file["Year"].between(2012 , 2014)
file[between_2012_to_2014]
# Out:
#                                                      Rank Platform    Year  \
# Name
# Grand Theft Auto V                                     17      PS3  2013.0
# Grand Theft Auto V                                     24     X360  2013.0
# Pokemon X/Pokemon Y                                    33      3DS  2013.0
# Call of Duty: Black Ops II                             35      PS3  2012.0
# Call of Duty: Black Ops II                             36     X360  2012.0
# ...                                                   ...      ...     ...
# Dramatical Murder Re:code                           16560      PSV  2014.0
# Hanasaku Manimani                                   16563      PSV  2014.0
# End of Nations                                      16569       PC  2012.0
# Fujiko F. Fujio Characters: Great Assembly! Sli...  16570      3DS  2014.0
# Grisaia no Kajitsu: La Fruit de la Grisaia          16574      PSP  2013.0
#
# ...
