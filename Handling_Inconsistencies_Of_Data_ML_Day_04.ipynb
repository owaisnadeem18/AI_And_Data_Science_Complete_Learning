# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = {

        'date': ['2021-12-01', '01-12-2022', '2022/12/01', '12-01-2021'],
    'country': ['USA', 'U.S.A.', 'America', 'United States'],
    'name': ['Aammar', 'Amaar', 'Hamza', 'Hazma'],
    'sales_2020': [100, 200, None, 200],
    'sales_2021': [None, 150, 300, 150]

}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#          date        country    name  sales_2020  sales_2021
# 0  2021-12-01            USA  Aammar       100.0         NaN
# 1  01-12-2022         U.S.A.   Amaar       200.0       150.0
# 2  2022/12/01        America   Hamza         NaN       300.0
# 3  12-01-2021  United States   Hazma       200.0       150.0

# %%
# standardizing date format

df['date'] = pd.to_datetime(df['date'] , errors = 'coerce')
df['date'] = df['date'].dt.strftime('%Y-%m-%d')

df.head()
# Out:
#          date        country    name  sales_2020  sales_2021
# 0  2021-12-01            USA  Aammar       100.0         NaN
# 1  2022-01-12         U.S.A.   Amaar       200.0       150.0
# 2  2022-12-01        America   Hamza         NaN       300.0
# 3  2021-12-01  United States   Hazma       200.0       150.0

# %%
country_maping = {'USA' : "United States" , 'U.S.A.' : "United States" , 'America' : "United States" }

df['country'] = df['country'].replace(country_maping)
df.head()
# Out:
#          date        country    name  sales_2020  sales_2021
# 0  2021-12-01  United States  Aammar       100.0         NaN
# 1  2022-01-12  United States   Amaar       200.0       150.0
# 2  2022-12-01  United States   Hamza         NaN       300.0
# 3  2021-12-01  United States   Hazma       200.0       150.0

# %%
df['name'] = df['name'].replace({"Amaar" :"Aammar Tufail" , "Aammar" :"Aammar Tufail" , "Hazma": "Hamza"})

df.head()
# Out:
#          date        country           name  sales_2020  sales_2021
# 0  2021-12-01  United States  Aammar Tufail       100.0         NaN
# 1  2022-01-12  United States  Aammar Tufail       200.0       150.0
# 2  2022-12-01  United States          Hamza         NaN       300.0
# 3  2021-12-01  United States          Hamza       200.0       150.0

# %%
# removing duplicates

df = df.drop_duplicates("name")

df.head()
# Out:
#          date        country           name  sales_2020  sales_2021
# 0  2021-12-01  United States  Aammar Tufail       100.0         NaN
# 2  2022-12-01  United States          Hamza         NaN       300.0

# %%
# 5. Resolving Contradictory Data
# For demonstration, let's assume sales_2021 should always be higher than sales_2020
# We'll remove rows where this condition is not met
df = df.drop(df[df['sales_2021'] <= df['sales_2020']].index)
df.head()
# Out:
#          date        country           name  sales_2020  sales_2021
# 0  2021-12-01  United States  Aammar Tufail       100.0         NaN
# 2  2022-12-01  United States          Hamza         NaN       300.0
