# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes = True)

# %%
file = pd.read_csv("/content/data_Lec13 (1).csv")

# %%
file.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
file.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
file.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
file = file.drop(["Vehicle Size"] , axis = 1 )

# %%
file.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Style  highway MPG  city mpg  \
# ...

# %%
file = file.rename(columns = {"Year" : "Saal" , "Number of Doors" : "Total Doors" , "Engine Cylinders" : "Cylinders"})

file.head()
# Out:
#   Make       Model  Saal             Engine Fuel Type  Engine HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0        6.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0        6.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0        6.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0        6.0
#
#   Transmission Type     Driven_Wheels  Total Doors  \
# 0            MANUAL  rear wheel drive          2.0
# 1            MANUAL  rear wheel drive          2.0
# 2            MANUAL  rear wheel drive          2.0
# 3            MANUAL  rear wheel drive          2.0
# 4            MANUAL  rear wheel drive          2.0
#
#                          Market Category Vehicle Style  highway MPG  city mpg  \
# 0  Factory Tuner,Luxury,High-Performance         Coupe           26        19
# ...

# %%
file.shape
duplicate_rows_find_out = file[file.duplicated()]
print(duplicate_rows_find_out.shape) # Now remove these duplicated rows from your data set...
# Out:
# (726, 15)

# %%
file.count()
# Out:
# Make                 11914
# Model                11914
# Saal                 11914
# Engine Fuel Type     11911
# Engine HP            11845
# Cylinders            11884
# Transmission Type    11914
# Driven_Wheels        11914
# Total Doors          11908
# Market Category       8172
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
file = file.drop_duplicates()
file.shape
# Out:
# (11188, 15)

# %%
file.count()
# Out:
# Make                 11188
# Model                11188
# Saal                 11188
# Engine Fuel Type     11185
# Engine HP            11119
# Cylinders            11158
# Transmission Type    11188
# Driven_Wheels        11188
# Total Doors          11182
# Market Category       7823
# Vehicle Style        11188
# highway MPG          11188
# city mpg             11188
# Popularity           11188
# MSRP                 11188
# dtype: int64

# %%
print(file.isnull().sum())
# Out:
# Make                    0
# Model                   0
# Saal                    0
# Engine Fuel Type        3
# Engine HP              69
# Cylinders              30
# Transmission Type       0
# Driven_Wheels           0
# Total Doors             6
# Market Category      3365
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
file = file.dropna() # It will remove all the missing values from our data set
file.count()
# Out:
# Make                 7735
# Model                7735
# Saal                 7735
# Engine Fuel Type     7735
# Engine HP            7735
# Cylinders            7735
# Transmission Type    7735
# Driven_Wheels        7735
# Total Doors          7735
# Market Category      7735
# Vehicle Style        7735
# highway MPG          7735
# city mpg             7735
# Popularity           7735
# MSRP                 7735
# dtype: int64

# %%
# sns.boxplot(x=df['HP'])
sns.boxplot(x=file["Engine HP"])
# Out:
# <Axes: xlabel='Engine HP'>

# %%
file.head()
# Out:
#   Make       Model  Saal             Engine Fuel Type  Engine HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0        6.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0        6.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0        6.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0        6.0
#
#   Transmission Type     Driven_Wheels  Total Doors  \
# 0            MANUAL  rear wheel drive          2.0
# 1            MANUAL  rear wheel drive          2.0
# 2            MANUAL  rear wheel drive          2.0
# 3            MANUAL  rear wheel drive          2.0
# 4            MANUAL  rear wheel drive          2.0
#
#                          Market Category Vehicle Style  highway MPG  city mpg  \
# 0  Factory Tuner,Luxury,High-Performance         Coupe           26        19
# ...

# %%
sns.boxplot(x= file["MSRP"])
# Out:
# <Axes: xlabel='MSRP'>

# %%
Q1 = file.quantile(0.25)

Q3 = file.quantile(0.75)

IQR = Q3 - Q1

print(IQR)
# Out:
# Saal               6.0
# Engine HP        131.0
# Cylinders          2.0
# Total Doors        2.0
# highway MPG        8.0
# city mpg           6.0
# Popularity      1489.0
# MSRP           23252.5
# dtype: float64
# <ipython-input-45-1c49c39e833c>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = file.quantile(0.25)
# <ipython-input-45-1c49c39e833c>:3: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = file.quantile(0.75)

# %%
sns.boxplot(x = file["MSRP"])
# Out:
# <Axes: xlabel='MSRP'>

# %%
file.corr()
# Out:
# <ipython-input-47-ba42001a7aab>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   file.corr()
#                  Saal  Engine HP  Cylinders  Total Doors  highway MPG  \
# Saal         1.000000   0.234461  -0.051369     0.189846     0.219893
# Engine HP    0.234461   1.000000   0.811138    -0.212644    -0.468328
# Cylinders   -0.051369   0.811138   1.000000    -0.192441    -0.597864
# Total Doors  0.189846  -0.212644  -0.192441     1.000000     0.114555
# highway MPG  0.219893  -0.468328  -0.597864     0.114555     1.000000
# city mpg     0.183083  -0.510151  -0.613399     0.150835     0.818331
# Popularity   0.126803   0.036553   0.010051    -0.042345     0.033672
# MSRP         0.125162   0.655522   0.589557    -0.193079    -0.255595
#
#              city mpg  Popularity      MSRP
# ...
